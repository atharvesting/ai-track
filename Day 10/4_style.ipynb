# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fpath = 'spotify.csv'
data = pd.read_csv(fpath, index_col="Date", parse_dates=True)

# %%
plt.figure(figsize=(12, 6))
# sns.set_style("darkgrid")  # graph style changes to a dark grid style
# sns.set_style("ticks")
sns.lineplot(data=data)
# Out:
# <Axes: xlabel='Date'>
